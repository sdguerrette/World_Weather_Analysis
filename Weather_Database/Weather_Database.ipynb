# %%
#Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time
from datetime import datetime
from citipy import citipy
from config import google_key as gkey 
from config import weather_key as wkey

# %%
#create a set of random latitude and longitute combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
#put put lat_lng pairs into a list
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + wkey

# %%
#testing url retreival

# city_url = url + '&q=rio+de+janeiro'
# rio = requests.get(city_url).json()
# rio_description = rio['weather'][0]['description']
# print(rio_description)
# Out:
# overcast clouds

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through all the cities in our list
for i, city in enumerate(cities):
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i>=50):
        set_count +=1
        record_count=1
        time.sleep(60)
    #create an endpoint URL with each city
    city_url = url + '&q=' + city.replace(' ' ,'+')
    #Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    #add 1 to the record count
    record_count +=1
    #Run an API request for each of the cities
    try:
        #parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #parse the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        weather_description = city_weather['weather'][0]['description']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity'] 
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
      #append the city info into the city_data list
        city_data.append({'City':city.title(),
                         'Lat': city_lat,
                         'Lng':city_lng,
                         'Max Temp':city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness':city_clouds,
                         'Wind Speed': city_wind,
                         'Country':city_country,
                         'Description': weather_description})
    #if an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
#indicate that Data loading is complete
print('------------------------------')
print('Data Retrieval Complete')
print('------------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pochutla
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | hun
# Processing Record 4 of Set 1 | lima
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | micheweni
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | bantayan
# Processing Record 12 of Set 1 | hofn
# Processing Record 13 of Set 1 | navirai
# Processing Record 14 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | olafsvik
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | novyy svit
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | chulman
# Processing Record 25 of Set 1 | katsuura
# Processing Record 26 of Set 1 | komsomolskiy
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | grindavik
# Processing Record 29 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 1 | bandipur
# Processing Record 31 of Set 1 | wollongong
# Processing Record 32 of Set 1 | sitka
# Processing Record 33 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 1 | raymondville
# Processing Record 39 of Set 1 | barcelos
# Processing Record 40 of Set 1 | beckley
# Processing Record 41 of Set 1 | fairbanks
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | flin flon
# Processing Record 44 of Set 1 | guanhaes
# Processing Record 45 of Set 1 | muroto
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | sarakhs
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | dharchula
# Processing Record 50 of Set 1 | iskateley
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | ketchikan
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | teguldet
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | saint george
# Processing Record 8 of Set 2 | leningradskiy
# Processing Record 9 of Set 2 | bemidji
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | salalah
# Processing Record 14 of Set 2 | laguna
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | oktyabrskiy
# Processing Record 21 of Set 2 | uige
# Processing Record 22 of Set 2 | itarema
# Processing Record 23 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 2 | zhigansk
# Processing Record 25 of Set 2 | denpasar
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | te anau
# Processing Record 28 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 2 | bagan
# Processing Record 31 of Set 2 | yarada
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | horb
# Processing Record 34 of Set 2 | kloulklubed
# Processing Record 35 of Set 2 | ust-kuyga
# Processing Record 36 of Set 2 | saint-pierre
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | shubarkuduk
# Processing Record 39 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 2 | lata
# Processing Record 41 of Set 2 | marsa matruh
# Processing Record 42 of Set 2 | bahar
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | esperance
# Processing Record 45 of Set 2 | samarkand
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | putyatino
# Processing Record 48 of Set 2 | kashi
# Processing Record 49 of Set 2 | puerto del rosario
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | sheltozero
# Processing Record 3 of Set 3 | cape town
# Processing Record 4 of Set 3 | ramanuj ganj
# Processing Record 5 of Set 3 | albion
# Processing Record 6 of Set 3 | camacha
# Processing Record 7 of Set 3 | harper
# Processing Record 8 of Set 3 | qianan
# Processing Record 9 of Set 3 | inhambane
# Processing Record 10 of Set 3 | zaozerne
# Processing Record 11 of Set 3 | madaoua
# Processing Record 12 of Set 3 | kerman
# Processing Record 13 of Set 3 | hermanus
# Processing Record 14 of Set 3 | alpena
# Processing Record 15 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | labuhan
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | jabinyanah
# Processing Record 21 of Set 3 | mankachar
# Processing Record 22 of Set 3 | cherskiy
# Processing Record 23 of Set 3 | codrington
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | henties bay
# Processing Record 27 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 3 | shumskiy
# Processing Record 29 of Set 3 | mount gambier
# Processing Record 30 of Set 3 | grand-santi
# Processing Record 31 of Set 3 | qaanaaq
# Processing Record 32 of Set 3 | ilheus
# Processing Record 33 of Set 3 | kavaratti
# Processing Record 34 of Set 3 | cidreira
# Processing Record 35 of Set 3 | yuzhno-kurilsk
# Processing Record 36 of Set 3 | coquimbo
# Processing Record 37 of Set 3 | tuktoyaktuk
# Processing Record 38 of Set 3 | khuzdar
# Processing Record 39 of Set 3 | fortuna
# Processing Record 40 of Set 3 | champerico
# Processing Record 41 of Set 3 | tokur
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | butaritari
# Processing Record 44 of Set 3 | sibolga
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | sioux lookout
# Processing Record 47 of Set 3 | jamestown
# Processing Record 48 of Set 3 | cabo san lucas
# Processing Record 49 of Set 3 | cabedelo
# Processing Record 50 of Set 3 | coahuayana
# Processing Record 1 of Set 4 | bilibino
# Processing Record 2 of Set 4 | georgetown
# Processing Record 3 of Set 4 | muli
# Processing Record 4 of Set 4 | tiksi
# Processing Record 5 of Set 4 | vila velha
# Processing Record 6 of Set 4 | faanui
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | takaungu
# Processing Record 9 of Set 4 | manokwari
# Processing Record 10 of Set 4 | mareeba
# Processing Record 11 of Set 4 | ponta do sol
# Processing Record 12 of Set 4 | batemans bay
# Processing Record 13 of Set 4 | okahandja
# Processing Record 14 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | hambantota
# Processing Record 16 of Set 4 | rocha
# Processing Record 17 of Set 4 | bengkulu
# Processing Record 18 of Set 4 | richards bay
# Processing Record 19 of Set 4 | grand gaube
# Processing Record 20 of Set 4 | flinders
# Processing Record 21 of Set 4 | kununurra
# Processing Record 22 of Set 4 | narrabri
# Processing Record 23 of Set 4 | umm lajj
# Processing Record 24 of Set 4 | jiwani
# Processing Record 25 of Set 4 | ribeira brava
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | marsabit
# Processing Record 28 of Set 4 | dragesti
# Processing Record 29 of Set 4 | saraland
# Processing Record 30 of Set 4 | kasungu
# Processing Record 31 of Set 4 | mahebourg
# Processing Record 32 of Set 4 | isangel
# Processing Record 33 of Set 4 | torbay
# Processing Record 34 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 4 | port moresby
# Processing Record 36 of Set 4 | tuatapere
# Processing Record 37 of Set 4 | smithers
# Processing Record 38 of Set 4 | hovd
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | provideniya
# Processing Record 41 of Set 4 | qasigiannguit
# Processing Record 42 of Set 4 | biloela
# Processing Record 43 of Set 4 | portland
# Processing Record 44 of Set 4 | college
# Processing Record 45 of Set 4 | pocola
# Processing Record 46 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 4 | kaseda
# Processing Record 48 of Set 4 | la ronge
# Processing Record 49 of Set 4 | mao
# Processing Record 50 of Set 4 | oktyabrskoye
# Processing Record 1 of Set 5 | tsiroanomandidy
# Processing Record 2 of Set 5 | mayo
# Processing Record 3 of Set 5 | castro
# Processing Record 4 of Set 5 | sao felix do xingu
# Processing Record 5 of Set 5 | la belgica
# Processing Record 6 of Set 5 | port alfred
# Processing Record 7 of Set 5 | gizo
# Processing Record 8 of Set 5 | linhai
# Processing Record 9 of Set 5 | santa fe
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | kaeo
# Processing Record 12 of Set 5 | ribeira grande
# Processing Record 13 of Set 5 | jacksonville
# Processing Record 14 of Set 5 | iracoubo
# Processing Record 15 of Set 5 | bereda
# Processing Record 16 of Set 5 | ghanzi
# Processing Record 17 of Set 5 | lavrentiya
# Processing Record 18 of Set 5 | palmer
# Processing Record 19 of Set 5 | port said
# Processing Record 20 of Set 5 | faya
# Processing Record 21 of Set 5 | gurlan
# Processing Record 22 of Set 5 | waycross
# Processing Record 23 of Set 5 | taltal
# Processing Record 24 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 5 | esmeraldas
# Processing Record 27 of Set 5 | nabire
# Processing Record 28 of Set 5 | sadao
# Processing Record 29 of Set 5 | geraldton
# Processing Record 30 of Set 5 | clyde river
# Processing Record 31 of Set 5 | mombetsu
# Processing Record 32 of Set 5 | beringovskiy
# Processing Record 33 of Set 5 | rapar
# Processing Record 34 of Set 5 | yenagoa
# Processing Record 35 of Set 5 | caravelas
# Processing Record 36 of Set 5 | muhos
# Processing Record 37 of Set 5 | shambu
# Processing Record 38 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 39 of Set 5 | poum
# Processing Record 40 of Set 5 | chakia
# Processing Record 41 of Set 5 | valparaiso
# Processing Record 42 of Set 5 | goure
# Processing Record 43 of Set 5 | namibe
# Processing Record 44 of Set 5 | atambua
# Processing Record 45 of Set 5 | utica
# Processing Record 46 of Set 5 | bambanglipuro
# Processing Record 47 of Set 5 | zlitan
# Processing Record 48 of Set 5 | hami
# Processing Record 49 of Set 5 | padang
# Processing Record 50 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 6 | yar-sale
# Processing Record 2 of Set 6 | mut
# Processing Record 3 of Set 6 | ratnagiri
# Processing Record 4 of Set 6 | hammerfest
# Processing Record 5 of Set 6 | awjilah
# Processing Record 6 of Set 6 | adrar
# Processing Record 7 of Set 6 | barsovo
# Processing Record 8 of Set 6 | derzhavinsk
# Processing Record 9 of Set 6 | asau
# Processing Record 10 of Set 6 | varadero
# Processing Record 11 of Set 6 | tautira
# Processing Record 12 of Set 6 | jacareacanga
# Processing Record 13 of Set 6 | arraial do cabo
# Processing Record 14 of Set 6 | vila
# Processing Record 15 of Set 6 | port-gentil
# Processing Record 16 of Set 6 | souillac
# Processing Record 17 of Set 6 | hlohovec
# Processing Record 18 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 19 of Set 6 | longyearbyen
# Processing Record 20 of Set 6 | ilulissat
# Processing Record 21 of Set 6 | nantucket
# Processing Record 22 of Set 6 | hamilton
# Processing Record 23 of Set 6 | kingaroy
# Processing Record 24 of Set 6 | cockburn town
# Processing Record 25 of Set 6 | sao filipe
# Processing Record 26 of Set 6 | paso de patria
# Processing Record 27 of Set 6 | bairiki
# Processing Record 28 of Set 6 | sulangan
# Processing Record 29 of Set 6 | martapura
# Processing Record 30 of Set 6 | kamaishi
# Processing Record 31 of Set 6 | mogadishu
# Processing Record 32 of Set 6 | chantada
# Processing Record 33 of Set 6 | sabha
# Processing Record 34 of Set 6 | jamkhed
# Processing Record 35 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 37 of Set 6 | nioro
# Processing Record 38 of Set 6 | kruisfontein
# Processing Record 39 of Set 6 | imeni poliny osipenko
# Processing Record 40 of Set 6 | port hardy
# Processing Record 41 of Set 6 | kidal
# Processing Record 42 of Set 6 | vila franca do campo
# Processing Record 43 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 6 | seka
# Processing Record 45 of Set 6 | chokurdakh
# Processing Record 46 of Set 6 | kungurtug
# Processing Record 47 of Set 6 | sapa
# Processing Record 48 of Set 6 | san angelo
# Processing Record 49 of Set 6 | prince rupert
# Processing Record 50 of Set 6 | bilma
# Processing Record 1 of Set 7 | almaznyy
# Processing Record 2 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 7 | sofiysk
# City not found. Skipping...
# Processing Record 4 of Set 7 | aasiaat
# Processing Record 5 of Set 7 | tupik
# Processing Record 6 of Set 7 | mugango
# Processing Record 7 of Set 7 | velykyy burluk
# Processing Record 8 of Set 7 | saquarema
# Processing Record 9 of Set 7 | tahe
# Processing Record 10 of Set 7 | karratha
# Processing Record 11 of Set 7 | pagondas
# City not found. Skipping...
# Processing Record 12 of Set 7 | yelyzavethradka
# Processing Record 13 of Set 7 | pangody
# Processing Record 14 of Set 7 | aklavik
# Processing Record 15 of Set 7 | ponta delgada
# Processing Record 16 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 7 | santiago
# Processing Record 18 of Set 7 | inverness
# Processing Record 19 of Set 7 | waipawa
# Processing Record 20 of Set 7 | margate
# Processing Record 21 of Set 7 | semey
# Processing Record 22 of Set 7 | mahaicony
# City not found. Skipping...
# Processing Record 23 of Set 7 | bud
# Processing Record 24 of Set 7 | inuvik
# Processing Record 25 of Set 7 | hvide sande
# Processing Record 26 of Set 7 | kurchum
# Processing Record 27 of Set 7 | afua
# Processing Record 28 of Set 7 | saint anthony
# Processing Record 29 of Set 7 | bull savanna
# Processing Record 30 of Set 7 | bonavista
# Processing Record 31 of Set 7 | kosonsoy
# Processing Record 32 of Set 7 | havelock
# Processing Record 33 of Set 7 | thaba-tseka
# Processing Record 34 of Set 7 | vanimo
# Processing Record 35 of Set 7 | lasa
# Processing Record 36 of Set 7 | kropotkin
# Processing Record 37 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 7 | rajsamand
# Processing Record 39 of Set 7 | plettenberg bay
# Processing Record 40 of Set 7 | preobrazheniye
# Processing Record 41 of Set 7 | carnarvon
# Processing Record 42 of Set 7 | san patricio
# Processing Record 43 of Set 7 | iqaluit
# Processing Record 44 of Set 7 | da lat
# Processing Record 45 of Set 7 | nador
# Processing Record 46 of Set 7 | stephenville
# Processing Record 47 of Set 7 | lagoa
# Processing Record 48 of Set 7 | san quintin
# Processing Record 49 of Set 7 | ziarat
# Processing Record 50 of Set 7 | ulaangom
# Processing Record 1 of Set 8 | dolores
# Processing Record 2 of Set 8 | llanes
# Processing Record 3 of Set 8 | luoyang
# Processing Record 4 of Set 8 | gallup
# Processing Record 5 of Set 8 | bolshaya glushitsa
# Processing Record 6 of Set 8 | terney
# Processing Record 7 of Set 8 | kabare
# Processing Record 8 of Set 8 | banjarmasin
# Processing Record 9 of Set 8 | touros
# Processing Record 10 of Set 8 | hasaki
# Processing Record 11 of Set 8 | vardo
# Processing Record 12 of Set 8 | pringsewu
# Processing Record 13 of Set 8 | teknaf
# Processing Record 14 of Set 8 | senahu
# Processing Record 15 of Set 8 | mobaye
# Processing Record 16 of Set 8 | yerbogachen
# Processing Record 17 of Set 8 | milyutinskaya
# Processing Record 18 of Set 8 | chicama
# Processing Record 19 of Set 8 | vostok
# Processing Record 20 of Set 8 | vrangel
# Processing Record 21 of Set 8 | sangar
# Processing Record 22 of Set 8 | cartagena
# Processing Record 23 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 24 of Set 8 | karangampel
# Processing Record 25 of Set 8 | acari
# Processing Record 26 of Set 8 | dunedin
# Processing Record 27 of Set 8 | kamenskiy
# Processing Record 28 of Set 8 | quatre cocos
# Processing Record 29 of Set 8 | puerto suarez
# Processing Record 30 of Set 8 | cuiluan
# Processing Record 31 of Set 8 | mopipi
# Processing Record 32 of Set 8 | nueva gerona
# Processing Record 33 of Set 8 | amuntai
# Processing Record 34 of Set 8 | bintulu
# Processing Record 35 of Set 8 | vlore
# Processing Record 36 of Set 8 | winkler
# Processing Record 37 of Set 8 | viesite
# Processing Record 38 of Set 8 | mweka
# Processing Record 39 of Set 8 | bitung
# Processing Record 40 of Set 8 | kindu
# Processing Record 41 of Set 8 | puerto escondido
# Processing Record 42 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 43 of Set 8 | concepcion del uruguay
# Processing Record 44 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 8 | jardim
# Processing Record 46 of Set 8 | salinopolis
# Processing Record 47 of Set 8 | moldava nad bodvou
# Processing Record 48 of Set 8 | mitsamiouli
# Processing Record 49 of Set 8 | mayfield
# Processing Record 50 of Set 8 | husavik
# Processing Record 1 of Set 9 | ganzhou
# Processing Record 2 of Set 9 | tinaquillo
# Processing Record 3 of Set 9 | sayyan
# Processing Record 4 of Set 9 | raigarh
# Processing Record 5 of Set 9 | simao
# Processing Record 6 of Set 9 | mount isa
# Processing Record 7 of Set 9 | zaporizhzhya
# Processing Record 8 of Set 9 | moron
# Processing Record 9 of Set 9 | xuanwu
# Processing Record 10 of Set 9 | acala
# Processing Record 11 of Set 9 | saldanha
# Processing Record 12 of Set 9 | akyab
# Processing Record 13 of Set 9 | gat
# Processing Record 14 of Set 9 | ust-omchug
# Processing Record 15 of Set 9 | formosa
# Processing Record 16 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 9 | prokopyevsk
# Processing Record 18 of Set 9 | galyugayevskaya
# Processing Record 19 of Set 9 | tura
# Processing Record 20 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 21 of Set 9 | bridlington
# Processing Record 22 of Set 9 | ushtobe
# Processing Record 23 of Set 9 | de-kastri
# Processing Record 24 of Set 9 | indiaroba
# Processing Record 25 of Set 9 | aitape
# Processing Record 26 of Set 9 | auce
# Processing Record 27 of Set 9 | santa rosalia
# Processing Record 28 of Set 9 | ostrovnoy
# Processing Record 29 of Set 9 | nanortalik
# Processing Record 30 of Set 9 | bontang
# Processing Record 31 of Set 9 | lagunas
# Processing Record 32 of Set 9 | tapes
# Processing Record 33 of Set 9 | panlaitan
# Processing Record 34 of Set 9 | westport
# Processing Record 35 of Set 9 | tir pol
# City not found. Skipping...
# Processing Record 36 of Set 9 | roald
# Processing Record 37 of Set 9 | nouakchott
# Processing Record 38 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 39 of Set 9 | kumta
# Processing Record 40 of Set 9 | gazanjyk
# Processing Record 41 of Set 9 | mugur-aksy
# Processing Record 42 of Set 9 | mimongo
# Processing Record 43 of Set 9 | conceicao do araguaia
# Processing Record 44 of Set 9 | sirnach
# Processing Record 45 of Set 9 | jablanica
# Processing Record 46 of Set 9 | fomboni
# Processing Record 47 of Set 9 | ahipara
# Processing Record 48 of Set 9 | marsh harbour
# Processing Record 49 of Set 9 | karaton
# Processing Record 50 of Set 9 | herouville-saint-clair
# Processing Record 1 of Set 10 | surgut
# Processing Record 2 of Set 10 | bartica
# Processing Record 3 of Set 10 | la paz
# Processing Record 4 of Set 10 | kimbe
# Processing Record 5 of Set 10 | mariestad
# Processing Record 6 of Set 10 | aswan
# Processing Record 7 of Set 10 | rawson
# Processing Record 8 of Set 10 | progreso
# Processing Record 9 of Set 10 | korcula
# Processing Record 10 of Set 10 | mendoza
# Processing Record 11 of Set 10 | qaqortoq
# Processing Record 12 of Set 10 | marawi
# Processing Record 13 of Set 10 | honiara
# Processing Record 14 of Set 10 | kathmandu
# Processing Record 15 of Set 10 | santiago del estero
# Processing Record 16 of Set 10 | newport
# Processing Record 17 of Set 10 | coracora
# Processing Record 18 of Set 10 | naze
# Processing Record 19 of Set 10 | tezu
# Processing Record 20 of Set 10 | parana
# Processing Record 21 of Set 10 | yeppoon
# Processing Record 22 of Set 10 | west plains
# Processing Record 23 of Set 10 | la cruz
# Processing Record 24 of Set 10 | guerrero negro
# Processing Record 25 of Set 10 | morant bay
# Processing Record 26 of Set 10 | ust-nera
# Processing Record 27 of Set 10 | luanda
# Processing Record 28 of Set 10 | tateyama
# Processing Record 29 of Set 10 | mehamn
# Processing Record 30 of Set 10 | gatton
# Processing Record 31 of Set 10 | haines junction
# Processing Record 32 of Set 10 | karaj
# Processing Record 33 of Set 10 | valera
# Processing Record 34 of Set 10 | vestmannaeyjar
# Processing Record 35 of Set 10 | ryazan
# Processing Record 36 of Set 10 | tommot
# Processing Record 37 of Set 10 | rio cuarto
# Processing Record 38 of Set 10 | porto novo
# Processing Record 39 of Set 10 | de aar
# Processing Record 40 of Set 10 | biak
# Processing Record 41 of Set 10 | hollister
# Processing Record 42 of Set 10 | san lawrenz
# Processing Record 43 of Set 10 | talnakh
# Processing Record 44 of Set 10 | guane
# Processing Record 45 of Set 10 | tessalit
# Processing Record 46 of Set 10 | mattru
# Processing Record 47 of Set 10 | emba
# Processing Record 48 of Set 10 | los llanos de aridane
# Processing Record 49 of Set 10 | zhanaozen
# Processing Record 50 of Set 10 | carsamba
# Processing Record 1 of Set 11 | wadena
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | tomatlan
# Processing Record 4 of Set 11 | lakes entrance
# Processing Record 5 of Set 11 | klaksvik
# Processing Record 6 of Set 11 | gumdag
# Processing Record 7 of Set 11 | barras
# Processing Record 8 of Set 11 | goderich
# Processing Record 9 of Set 11 | yuli
# Processing Record 10 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 11 | noumea
# Processing Record 12 of Set 11 | hualmay
# Processing Record 13 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 11 | talaya
# Processing Record 15 of Set 11 | gerash
# Processing Record 16 of Set 11 | wewak
# Processing Record 17 of Set 11 | moorhead
# Processing Record 18 of Set 11 | dukat
# Processing Record 19 of Set 11 | baculin
# Processing Record 20 of Set 11 | gamba
# Processing Record 21 of Set 11 | buzdyak
# Processing Record 22 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 11 | muros
# Processing Record 24 of Set 11 | alofi
# Processing Record 25 of Set 11 | tungor
# Processing Record 26 of Set 11 | kokkola
# Processing Record 27 of Set 11 | pisco
# Processing Record 28 of Set 11 | sola
# Processing Record 29 of Set 11 | kaili
# Processing Record 30 of Set 11 | gisborne
# Processing Record 31 of Set 11 | saint-augustin
# Processing Record 32 of Set 11 | salme
# Processing Record 33 of Set 11 | panguna
# Processing Record 34 of Set 11 | constitucion
# Processing Record 35 of Set 11 | kondoa
# Processing Record 36 of Set 11 | nome
# Processing Record 37 of Set 11 | praia da vitoria
# Processing Record 38 of Set 11 | tamandare
# Processing Record 39 of Set 11 | sulina
# Processing Record 40 of Set 11 | ornskoldsvik
# Processing Record 41 of Set 11 | kahului
# Processing Record 42 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 11 | santa cruz
# Processing Record 44 of Set 11 | coihaique
# Processing Record 45 of Set 11 | figeac
# Processing Record 46 of Set 11 | cheremukhovo
# Processing Record 47 of Set 11 | victor harbor
# Processing Record 48 of Set 11 | solnechnyy
# Processing Record 49 of Set 11 | moussoro
# Processing Record 50 of Set 11 | acapulco
# Processing Record 1 of Set 12 | beli potok
# Processing Record 2 of Set 12 | vernon
# Processing Record 3 of Set 12 | vilyuysk
# Processing Record 4 of Set 12 | linhares
# Processing Record 5 of Set 12 | pierre
# Processing Record 6 of Set 12 | kyren
# Processing Record 7 of Set 12 | alice springs
# Processing Record 8 of Set 12 | tucuman
# Processing Record 9 of Set 12 | paamiut
# Processing Record 10 of Set 12 | elat
# Processing Record 11 of Set 12 | mecca
# Processing Record 12 of Set 12 | atar
# Processing Record 13 of Set 12 | myitkyina
# Processing Record 14 of Set 12 | mbalmayo
# Processing Record 15 of Set 12 | kharp
# Processing Record 16 of Set 12 | shatsk
# Processing Record 17 of Set 12 | belaya gora
# Processing Record 18 of Set 12 | ancud
# Processing Record 19 of Set 12 | matara
# Processing Record 20 of Set 12 | baykit
# Processing Record 21 of Set 12 | mykolayivka
# Processing Record 22 of Set 12 | tongren
# Processing Record 23 of Set 12 | pacific grove
# Processing Record 24 of Set 12 | la asuncion
# Processing Record 25 of Set 12 | lethem
# Processing Record 26 of Set 12 | rafai
# Processing Record 27 of Set 12 | beyneu
# Processing Record 28 of Set 12 | bongaigaon
# Processing Record 29 of Set 12 | gushi
# Processing Record 30 of Set 12 | lompoc
# Processing Record 31 of Set 12 | ponce
# Processing Record 32 of Set 12 | palmerston
# Processing Record 33 of Set 12 | sidney
# Processing Record 34 of Set 12 | huarmey
# Processing Record 35 of Set 12 | shimanovsk
# Processing Record 36 of Set 12 | chernyshevskiy
# Processing Record 37 of Set 12 | razole
# Processing Record 38 of Set 12 | rovaniemi
# Processing Record 39 of Set 12 | ngunguru
# Processing Record 40 of Set 12 | dodge city
# Processing Record 41 of Set 12 | coffs harbour
# Processing Record 42 of Set 12 | erzin
# Processing Record 43 of Set 12 | killybegs
# Processing Record 44 of Set 12 | ames
# Processing Record 45 of Set 12 | babu
# Processing Record 46 of Set 12 | makakilo city
# Processing Record 47 of Set 12 | tabuk
# Processing Record 48 of Set 12 | qingyuan
# Processing Record 49 of Set 12 | porto walter
# Processing Record 50 of Set 12 | nishihara
# Processing Record 1 of Set 13 | jiayuguan
# Processing Record 2 of Set 13 | northam
# Processing Record 3 of Set 13 | wampusirpi
# City not found. Skipping...
# Processing Record 4 of Set 13 | pozo colorado
# Processing Record 5 of Set 13 | canarana
# Processing Record 6 of Set 13 | atlantic city
# Processing Record 7 of Set 13 | pabianice
# Processing Record 8 of Set 13 | leh
# Processing Record 9 of Set 13 | gao
# Processing Record 10 of Set 13 | ilirska bistrica
# Processing Record 11 of Set 13 | puerto quijarro
# Processing Record 12 of Set 13 | chino valley
# Processing Record 13 of Set 13 | quanzhou
# Processing Record 14 of Set 13 | burica
# City not found. Skipping...
# Processing Record 15 of Set 13 | korla
# Processing Record 16 of Set 13 | mangai
# Processing Record 17 of Set 13 | lumeje
# Processing Record 18 of Set 13 | port blair
# Processing Record 19 of Set 13 | darhan
# Processing Record 20 of Set 13 | sorland
# Processing Record 21 of Set 13 | kaa-khem
# Processing Record 22 of Set 13 | mandalgovi
# Processing Record 23 of Set 13 | saran
# Processing Record 24 of Set 13 | ambon
# Processing Record 25 of Set 13 | petauke
# Processing Record 26 of Set 13 | puerto el triunfo
# Processing Record 27 of Set 13 | buala
# Processing Record 28 of Set 13 | santa maria
# Processing Record 29 of Set 13 | corrales
# Processing Record 30 of Set 13 | berlevag
# Processing Record 31 of Set 13 | grand forks
# Processing Record 32 of Set 13 | puerto colombia
# Processing Record 33 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 13 | soldotna
# Processing Record 35 of Set 13 | khorramshahr
# Processing Record 36 of Set 13 | nagercoil
# Processing Record 37 of Set 13 | cayenne
# Processing Record 38 of Set 13 | askino
# Processing Record 39 of Set 13 | pimentel
# Processing Record 40 of Set 13 | abu zabad
# Processing Record 41 of Set 13 | vao
# Processing Record 42 of Set 13 | nhulunbuy
# Processing Record 43 of Set 13 | cienfuegos
# Processing Record 44 of Set 13 | cervo
# Processing Record 45 of Set 13 | meulaboh
# Processing Record 46 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 48 of Set 13 | luena
# Processing Record 49 of Set 13 | bansdih
# Processing Record 50 of Set 13 | shache
# Processing Record 1 of Set 14 | nyurba
# Processing Record 2 of Set 14 | sur
# Processing Record 3 of Set 14 | urengoy
# Processing Record 4 of Set 14 | medea
# Processing Record 5 of Set 14 | namatanai
# Processing Record 6 of Set 14 | perevolotskiy
# Processing Record 7 of Set 14 | sisimiut
# Processing Record 8 of Set 14 | warrington
# Processing Record 9 of Set 14 | mananara
# Processing Record 10 of Set 14 | kholodnyy
# Processing Record 11 of Set 14 | kulhudhuffushi
# Processing Record 12 of Set 14 | tahoua
# Processing Record 13 of Set 14 | lerwick
# Processing Record 14 of Set 14 | alizai
# Processing Record 15 of Set 14 | badlapur
# Processing Record 16 of Set 14 | tiarei
# Processing Record 17 of Set 14 | wahiawa
# Processing Record 18 of Set 14 | jaque
# Processing Record 19 of Set 14 | male
# Processing Record 20 of Set 14 | chipata
# Processing Record 21 of Set 14 | patterson
# Processing Record 22 of Set 14 | oranjestad
# Processing Record 23 of Set 14 | bom jesus dos perdoes
# Processing Record 24 of Set 14 | siocon
# Processing Record 25 of Set 14 | portel
# Processing Record 26 of Set 14 | khudumelapye
# Processing Record 27 of Set 14 | zheleznodorozhnyy
# Processing Record 28 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 14 | barra patuca
# Processing Record 30 of Set 14 | karlskrona
# Processing Record 31 of Set 14 | lyngseidet
# Processing Record 32 of Set 14 | ankazoabo
# Processing Record 33 of Set 14 | shitanjing
# Processing Record 34 of Set 14 | boguchany
# Processing Record 35 of Set 14 | kampot
# Processing Record 36 of Set 14 | tahta
# Processing Record 37 of Set 14 | tual
# Processing Record 38 of Set 14 | perambalur
# Processing Record 39 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 14 | rio de janeiro
# Processing Record 41 of Set 14 | soyo
# Processing Record 42 of Set 14 | suicheng
# Processing Record 43 of Set 14 | maxixe
# Processing Record 44 of Set 14 | gagnoa
# Processing Record 45 of Set 14 | san ramon
# Processing Record 46 of Set 14 | katangli
# Processing Record 47 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 48 of Set 14 | veraval
# Processing Record 49 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 14 | byron bay
# Processing Record 1 of Set 15 | port hedland
# Processing Record 2 of Set 15 | murgab
# Processing Record 3 of Set 15 | russell
# Processing Record 4 of Set 15 | pokhara
# Processing Record 5 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 15 | niquero
# Processing Record 7 of Set 15 | gumushane
# City not found. Skipping...
# Processing Record 8 of Set 15 | wrzesnia
# Processing Record 9 of Set 15 | drawsko pomorskie
# Processing Record 10 of Set 15 | abu samrah
# Processing Record 11 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 12 of Set 15 | chimoio
# Processing Record 13 of Set 15 | kupino
# Processing Record 14 of Set 15 | jinchengjiang
# City not found. Skipping...
# Processing Record 15 of Set 15 | usinsk
# Processing Record 16 of Set 15 | caluquembe
# Processing Record 17 of Set 15 | chimore
# Processing Record 18 of Set 15 | auki
# Processing Record 19 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 15 | charters towers
# Processing Record 22 of Set 15 | walvis bay
# Processing Record 23 of Set 15 | keetmanshoop
# Processing Record 24 of Set 15 | uvat
# Processing Record 25 of Set 15 | dafeng
# Processing Record 26 of Set 15 | beloha
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
print(len(city_data))
# Out:
# 669

# %%
#transform into dataframe
city_data_df = pd.DataFrame(city_data)
column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description']
city_data_df = city_data_df[column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Pochutla      MX  15.7432  -96.4661     82.22        53          13
# 1  Severo-Kurilsk      RU  50.6789  156.1250     36.07        92          86
# 2             Hun      LY  29.1268   15.9477     79.63        16          84
# 3            Lima      PE -12.0432  -77.0282     65.39        61           0
# 4    Punta Arenas      CL -53.1500  -70.9167     42.91        87          40
# 5         Ushuaia      AR -54.8000  -68.3000     40.66        65          20
# 6            Lebu      CL -37.6167  -73.6500     50.23        79           2
# 7       Micheweni      TZ  -4.9667   39.8333     79.25        82         100
# 8     New Norfolk      AU -42.7826  147.0587     61.66        63          94
# 9        Bantayan      PH  11.2000  123.7333     81.27        79         100
#
#    Wind Speed       Description
# 0        8.05        few clouds
# 1        9.64   overcast clouds
# 2       21.54     broken clouds
# 3       17.27         clear sky
# 4        8.05  scattered clouds
# 5        5.75        few clouds
# 6       13.56         clear sky
# 7       14.27        light rain
# 8        4.00   overcast clouds
# 9       11.36   overcast clouds

# %%
#create the output file (csv)
output_data_file = 'WeatherPy_Database.csv'
#export the city_data inta a csv
city_data_df.to_csv(output_data_file, index_label = 'City_ID')
